# %%
import numpy as np
import pandas as pd
import datetime

# %%
#1
rry = np.arange(6, 101, 4)

# %%
print(rry)
# Out:
# [ 6 10 14 18 22 26 30 34 38 42 46 50 54 58 62 66 70 74 78 82 86 90 94 98]

# %%
#2
a = np.array([1,2,3,np.nan,5,6,7,np.nan])
print(a)
# Out:
# [ 1.  2.  3. nan  5.  6.  7. nan]

# %%
drop = a[~np.isnan(a)]

# %%
print(drop)
# Out:
# [1. 2. 3. 5. 6. 7.]

# %%
#3
np.random.randint(100, size=(5, 6))
# Out:
# array([[52, 65, 24, 18, 21, 56],
#        [71, 59, 77, 96, 93, 68],
#        [ 6, 98, 86, 45, 52, 62],
#        [26, 29, 97, 24, 66, 86],
#        [27, 21, 10, 19, 83, 85]])

# %%
#4
series = pd.Series(np.take(list('abcdefghijklmnop'), np.random.randint(16, size=500))).unique()

# %%
print(series)
# Out:
# ['g' 'j' 'i' 'f' 'l' 'e' 'm' 'n' 'd' 'a' 'b' 'o' 'h' 'p' 'c' 'k']

# %%
#5
series2 = pd.Series(['01 Jan 2020', '10-19-2020', '20150303', '2013/04/04', '2012-05-05', '2013-06-06T12:20'])

# %%
series2.head(6)
# Out:
# 0         01 Jan 2020
# 1          10-19-2020
# 2            20150303
# 3          2013/04/04
# 4          2012-05-05
# 5    2013-06-06T12:20
# dtype: object

# %%
#6
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')

# %%
df.head(6)
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
# 5        Buick  Century  Midsize       14.2   15.7       17.3      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
# ...

# %%
df.shape
# Out:
# (93, 27)

# %%
df.rename(columns = {'Type':'TypeOfCar'}, inplace = True)

# %%
df.head(6)
# Out:
#   Manufacturer    Model TypeOfCar  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra     Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend   Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90   Compact       25.9   29.1       32.3      20.0
# 3         Audi      100   Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i   Midsize        NaN   30.0        NaN      22.0
# 5        Buick  Century   Midsize       14.2   15.7       17.3      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 138

# %%
#7
df.drop(columns=['EngineSize', 'Length'])
# Out:
#    Manufacturer    Model TypeOfCar  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra     Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend   Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90   Compact       25.9   29.1       32.3      20.0
# 3          Audi      100   Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i   Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...       ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan       Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat   Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado    Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240   Compact       21.8   22.7       23.5      21.0
# 92          NaN      850   Midsize       24.8   26.7       28.5      20.0
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# ...

# %%
#8
df1 = pd.DataFrame({'fruit': ['apple', 'banana', 'orange'] * 3,
                    'weight': ['high', 'medium', 'low'] * 3,
                    'price': np.random.randint(0, 15, 9)})

df2 = pd.DataFrame({'pazham': ['apple', 'orange', 'pine'] * 2,
                    'kilo': ['high', 'low'] * 3,
                    'price': np.random.randint(0, 15, 6)})

# %%
df_cd = pd.merge(df1, df2, how='inner')

# %%
print(df_cd)
# Out:
#     fruit  weight  price  pazham  kilo
# 0  banana  medium      4    pine  high
# 1  orange     low      6  orange  high
# 2  banana  medium      6  orange  high
# 3   apple    high      8  orange   low
# 4  orange     low      8  orange   low

# %%
df_cd.drop_duplicates()
# Out:
#     fruit  weight  price  pazham  kilo
# 0  banana  medium      4    pine  high
# 1  orange     low      6  orange  high
# 2  banana  medium      6  orange  high
# 3   apple    high      8  orange   low
# 4  orange     low      8  orange   low

# %%
#9
df8 = pd.DataFrame(["STD,City\tState",
"33,Kolkata\tWest Bengal",
"44,Chennai\tTamil Nadu",
"40,Hyderabad\tTelengana",
"80,Bangalore\tKarnataka"], columns=['row'])

# %%
df8.head(5)
# Out:
#                        row
# 0          STD,City\tState
# 1  33,Kolkata\tWest Bengal
# 2   44,Chennai\tTamil Nadu
# 3  40,Hyderabad\tTelengana
# 4  80,Bangalore\tKarnataka
